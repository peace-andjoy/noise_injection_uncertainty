# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
sensitivity = pd.read_csv('sensitivity.csv')

# %%
sensitivity
# Out:
#        type    acc  level  penalty
# 0     fixed  71.91  0.010      NaN
# 1     fixed  71.13  0.015      NaN
# 2     fixed  71.08  0.020      NaN
# 3     fixed  69.48  0.025      NaN
# 4     fixed  69.43  0.030      NaN
# 5     fixed  66.82  0.035      NaN
# 6     fixed  64.68  0.040      NaN
# 7   learned  71.19    NaN     0.00
# 8   learned  71.88    NaN    -0.01
# 9   learned  71.89    NaN    -0.02
# 10      NaN    NaN    NaN    -0.03
